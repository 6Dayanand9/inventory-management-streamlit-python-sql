# %%
import pandas as pd
import numpy as np
import streamlit as st
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost",
                               user="root",
                               password="123456",
                               database="supplychain")

# %%
conn.is_connected()
# Out:
# True

# %%
def connected_to_db():
    return mysql.connector.connect(host="localhost",
                               user="root",
                               password="123456",
                               database="supplychain")

# %%
connected_to_db().is_connected()
# Out:
# True

# %%
db = connected_to_db()

# %%
cursor = db.cursor(dictionary=True)
cursor

# %%
cursor.execute("SELECT count(*) as total_supplier FROM suppliers")

# %%
row=cursor.fetchone()

# %%
row.values()
# Out:
# dict_values([50])

# %%
list(row.values())[0]
# Out:
# 50

# %%
def get_basic_info(cursor):
    queries = {
        "Total Suppliers": """
            SELECT count(*) as total_suppliers 
            FROM suppliers;
        """,
    
        "Total Products": """
            SELECT count(*) as total_products 
            FROM products;
        """,
    
        "Total Categories Dealing": """
            SELECT count(distinct category) as total_category 
            FROM products;
        """,
    
        "Total Sales Value in Last 3 Months": """
            SELECT ROUND(SUM(ABS(se.change_quantity) * p.price), 2) AS total_sales_value_in_last_3_months
            FROM stock_entries AS se
            JOIN products p ON p.product_id = se.product_id
            WHERE se.change_type = 'Sale'
            AND se.entry_date >= (
                SELECT DATE_SUB(MAX(entry_date), INTERVAL 3 MONTH) 
                FROM stock_entries
            );
        """,
    
        "Total Restock Value in Last 3 Months": """
            SELECT ROUND(SUM(ABS(t2.change_quantity) * t1.price), 2) AS total_restock_value_in_last_3_months
            FROM products t1
            JOIN stock_entries t2 ON t1.product_id = t2.product_id
            WHERE t2.change_type = 'Restock'
            AND t2.entry_date >= (
                SELECT DATE_SUB(MAX(entry_date), INTERVAL 3 MONTH) 
                FROM stock_entries
            );
        """,
    
        "Products to Restock": """
            SELECT count(*) AS items_to_restock
            FROM products p
            WHERE p.stock_quantity < p.reorder_level
            AND p.product_id NOT IN (
                SELECT DISTINCT product_id 
                FROM reorders 
                WHERE status = 'Pending'
            );    
        """
    }
    result = {}

    for label,querie in queries.items():
        cursor.execute(querie)
        row = cursor.fetchone()
        result[label]=list(row.values())[0]
    return result

# %%
mydict=get_basic_info(cursor)

# %%
mydict
# Out:
# {'Total Suppliers': 50,
#  'Total Products': 204,
#  'Total Categories Dealing': 5,
#  'Total Sales Value in Last 3 Months': None,
#  'Total Restock Value in Last 3 Months': 4455000.0,
#  'Products to Restock': 14}

# %%
key=list(mydict.keys())
key
# Out:
# ['Total Suppliers',
#  'Total Products',
#  'Total Categories Dealing',
#  'Total Sales Value in Last 3 Months',
#  'Total Restock Value in Last 3 Months',
#  'Products to Restock']

# %%
mydict[key[0]]
# Out:
# 50

# %%
basic_info[key[i]])
# Out:
#   Cell In[19], line 1
#     basic_info[key[i]])
#                       ^
# SyntaxError: unmatched ')'

# %%
basic_infoo = get_basic_info(cursor)

# %%
basic_infoo
# Out:
# {'Total Suppliers': 50,
#  'Total Products': 204,
#  'Total Categories Dealing': 5,
#  'Total Sales Value in Last 3 Months': None,
#  'Total Restock Value in Last 3 Months': 4455000.0,
#  'Products to Restock': 14}

# %% [markdown]
# ### Queries no 2

# %%
queries = {
     "supplier contact details":

"""SELECT supplier_name,contact_name,email,phone  FROM suppliers;""",

"Product With there Supplier and Current stock":"""SELECT product_name,supplier_name,stock_quantity as current_stock_quantity,reorder_level   FROM suppliers t1
JOIN products t2
ON t1.supplier_id = t2.supplier_id
ORDER BY product_name;
""",

"Product needing Reorder":"""SELECT product_id,product_name,stock_quantity,reorder_level from products 
WHERE stock_quantity<reorder_level;"""


}

# %%
result = {}
for label,querie in queries.items():
    cursor.execute(querie)
    row = cursor.fetchall()
    print(label)
    table=pd.DataFrame(row)
    print(table)
    print()
# Out:
# supplier contact details
#                      supplier_name         contact_name  \
# 0                Anderson-Thompson         Bonnie Davis
# 1                      Rowland Ltd         Beth Stevens
# 2                   Baxter-Meadows           Lisa Lewis
# 3      Wilson, Graham and Williams       David Martinez
# 4        Smith, Kennedy and Moreno    Victoria Gonzalez
# 5                    Middleton LLC         Megan Miller
# 6                        Evans Inc       Danielle Moore
# 7   Lawrence, Garcia and Hernandez       Tamara Johnson
# 8         Young, Browning and Ware         Heather Hill
# 9        Newton, Valencia and Carr     Kimberly Collins
# 10           Vega, Cook and Miller       Stephen Rogers
# 11                   Mendoza-Jones        Daniel Archer
# 12                Gallagher-Miller        Michael Moore
# 13                 Miller-Martinez        Paula Morales
# 14                  Freeman-Gordon       Zachary Garcia
# 15                   Tucker-Arnold  Katherine Lopez DVM
# 16                       Gomez PLC      James Fernandez
# 17                      Moss-Evans       Jennifer Green
# 18                     Charles Inc             Lori Liu
# 19                  Ortega-Mahoney        Teresa Miller
# 20                   Mann-Marshall          Scott Watts
# 21                      Hudson Inc       Michael Nguyen
# 22                     Douglas Ltd       Jonathan White
# 23        Barker, White and Carson          Cesar Moore
# 24                     Barrett Ltd          Kim Wheeler
# 25                        Tran LLC       Anthony Jacobs
# 26        Franklin, Kane and Price         John Mueller
# 27       Stewart, Williams and Cox       Nichole Fuller
# 28                    Johnson-Bass        Megan Carroll
# 29                  Lloyd and Sons           Sarah Ross
# 30                     Taylor-Love       Daniel Mcgrath
# 31                   Elliott-Ayers          Kelly Avery
# 32               Reynolds-Phillips       Ashlee Montoya
# 33                      Moody-Vang      Joseph Peterson
# 34        Perez, Price and Wallace           James Rich
# 35                      Wong Group      Lauren Humphrey
# 36                     Kaufman Ltd        Chelsea Young
# 37                 Harris-Cummings       Jonathan Foley
# 38                    Turner-Davis       Matthew Walker
# 39                      Hall-Brown      Richard Ballard
# 40                     Clark Group   Stephen George DVM
# 41                   Henderson LLC          David Moore
# 42                        Rowe PLC      Kevin Mcpherson
# 43                   Rogers-Greene          Brady Brown
# 44    Patrick, Walter and Harrison         Mark Stevens
# 45                    Williams Ltd        Jeffery Allen
# 46                  Morgan-Andrews       Cathy Marshall
# 47                 Armstrong-Vance     Regina Nicholson
# 48                      Morgan Inc          Eric Farmer
# 49                  Hensley-Branch         Jordan Clark
#
#                                    email                   phone
# 0             zacharysanchez@hotmail.com       829.485.9853x0522
# 1                     joshua60@yahoo.com           (779)942-0726
# 2            andersonchristina@yahoo.com            449-766-7325
# 3                     abrown@hotmail.com     +1-653-827-5215x266
# 4              mary30@williams-moore.com      891-859-2775x35297
# 5               kelseywilliams@gmail.com   001-724-731-6199x4596
# 6                    ihoffman@warren.com     +1-951-447-1975x770
# 7              georgeherrera@hotmail.com     +1-635-460-8476x270
# 8                stephensjason@yahoo.com       (514)361-6411x489
# 9   jonathanjohnston@ashley-williams.com       762-368-3504x8972
# 10                ianderson@thompson.com     (545)747-7182x90685
# 11            clarketodd@bush-parker.com       077.020.6783x0807
# 12                     jesse95@gmail.com   +1-462-260-2525x67365
# 13                 floresderek@yahoo.com    +1-700-794-1809x5862
# 14                 angela33@humphrey.org            172-492-5671
# 15                michelle03@hotmail.com   001-661-335-2179x4217
# 16                lovewarren@harris.info            661-353-3289
# 17                 crystalroth@yahoo.com    +1-877-605-7924x7393
# 18               suzanne20@donaldson.net   +1-059-663-9297x67941
# 19                       ile@hotmail.com  001-415-849-5736x81908
# 20                colejoseph@hotmail.com              7317296630
# 21                   ucochran@osborn.com   +1-563-056-3764x85079
# 22                 michael15@hotmail.com  001-734-858-5527x84897
# 23                      qhogan@yahoo.com      (521)673-3153x7796
# 24                 william52@hotmail.com         +1-887-075-4700
# 25                     bdavis@fuller.com           (460)711-5746
# 26              mitchellpierce@gmail.com      230.183.6177x07682
# 27            mitchelllauren@hotmail.com    001-632-585-1111x529
# 28             fernandeztiffany@page.net              3531846182
# 29                  heathkaren@gmail.com        064-804-0646x199
# 30                perrykeith@kennedy.com        841-905-8982x711
# 31               joseph44@moore-soto.biz        768-127-8200x348
# 32         stonewesley@bowen-salinas.biz    +1-869-461-6007x4674
# 33                     hward@hotmail.com  001-530-230-6560x82908
# 34                natashapierce@knox.com            409.569.6703
# 35                  hayeseric@george.com       546-100-3064x5276
# 36                     wendy80@smith.net     (434)045-1867x11846
# 37                   david30@hotmail.com  001-034-624-8811x93395
# 38                    wmurphy@mathis.org      579-218-9601x54220
# 39                horneandrew@morgan.biz         +1-500-926-9681
# 40                royjessica@hotmail.com           (769)553-5373
# 41                  benjamin57@yahoo.com      122.972.2988x83535
# 42             marco90@edwards-moran.com       496-064-5206x9241
# 43          mcdowellkimberly@hotmail.com      883-297-7964x15108
# 44                   ymiller@hotmail.com       (561)464-9376x280
# 45                  jcooper@kim-cook.org       316-798-3465x4653
# 46                    fjohnson@gmail.com       088-233-7178x6223
# 47              jacobsonjohn@hotmail.com   +1-836-020-7265x14208
# 48               pricejaclyn@jimenez.com     (672)354-2529x76848
# 49                alextucker@freeman.com      (120)216-0730x2946
#
# Product With there Supplier and Current stock
#       product_name                 supplier_name  current_stock_quantity  \
# 0    Ability Snack                    Morgan Inc                     755
# 1      Account Toy             Anderson-Thompson                     758
# 2     Actually Toy                 Middleton LLC                     300
# 3      After Table  Patrick, Walter and Harrison                     590
# 4    Against Table      Franklin, Kane and Price                     267
# ..             ...                           ...                     ...
# 199     Whom Table                    Hudson Inc                     727
# 200    Whose Snack                    Wong Group                     182
# 201     Within Toy                 Rogers-Greene                      26
# 202     Within Toy               Harris-Cummings                     839
# 203   Writer Table             Anderson-Thompson                     700
#
#      reorder_level
# 0              113
# 1              190
# 2              181
# 3              165
# 4              161
# ..             ...
# 199            186
# 200            177
# 201            189
# 202            193
# 203            198
#
# [204 rows x 4 columns]
#
# Product needing Reorder
#     product_id     product_name  stock_quantity  reorder_level
# 0           19      Next Device              26            200
# 1           36      Race Device             108            183
# 2           46        Close Toy              46            161
# 3           50       Hard Snack              79            200
# 4           51      Staff Shirt             191            200
# 5           58        Floor Toy              67            194
# 6           62        Throw Toy              93            155
# 7          100       Fund Table              61            112
# 8          108  Executive Table              38            140
# 9          110    However Table              43             52
# 10         113   Certain Device              10            112
# 11         132       This Snack              20             66
# 12         136       Within Toy              26            189
# 13         137      Least Table              58             71
# 14         144   Building Snack               4             92
# 15         150     Return Table              39            182
# 16         153   Security Shirt              25             70
# 17         154     Manage Snack              63            171
# 18         160   Suddenly Table              53            166
# 19         165        Nor Snack             122            194
# 20         167      Discuss Toy             117            188
# 21         169       Four Shirt              63            175
# 22         173       Real Snack               4            182
# 23         180         Door Toy              11            178
# 24         185     Couple Shirt              50            138
# 25         192      Thought Toy             147            157
# 26         199      Book Device              46             66

# %%
result = {}
for label,querie in queries.items():
    cursor.execute(querie)
    row = cursor.fetchall()
    result[label]=row

result
# Out:
# {'supplier contact details': [{'supplier_name': 'Anderson-Thompson',
#    'contact_name': 'Bonnie Davis',
#    'email': 'zacharysanchez@hotmail.com',
#    'phone': '829.485.9853x0522'},
#   {'supplier_name': 'Rowland Ltd',
#    'contact_name': 'Beth Stevens',
#    'email': 'joshua60@yahoo.com',
#    'phone': '(779)942-0726'},
#   {'supplier_name': 'Baxter-Meadows',
#    'contact_name': 'Lisa Lewis',
#    'email': 'andersonchristina@yahoo.com',
#    'phone': '449-766-7325'},
#   {'supplier_name': 'Wilson, Graham and Williams',
#    'contact_name': 'David Martinez',
#    'email': 'abrown@hotmail.com',
#    'phone': '+1-653-827-5215x266'},
#   {'supplier_name': 'Smith, Kennedy and Moreno',
#    'contact_name': 'Victoria Gonzalez',
#    'email': 'mary30@williams-moore.com',
#    'phone': '891-859-2775x35297'},
#   {'supplier_name': 'Middleton LLC',
#    'contact_name': 'Megan Miller',
#    'email': 'kelseywilliams@gmail.com',
#    'phone': '001-724-731-6199x4596'},
#   {'supplier_name': 'Evans Inc',
#    'contact_name': 'Danielle Moore',
#    'email': 'ihoffman@warren.com',
#    'phone': '+1-951-447-1975x770'},
#   {'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'contact_name': 'Tamara Johnson',
#    'email': 'georgeherrera@hotmail.com',
#    'phone': '+1-635-460-8476x270'},
#   {'supplier_name': 'Young, Browning and Ware',
#    'contact_name': 'Heather Hill',
#    'email': 'stephensjason@yahoo.com',
#    'phone': '(514)361-6411x489'},
#   {'supplier_name': 'Newton, Valencia and Carr',
#    'contact_name': 'Kimberly Collins',
#    'email': 'jonathanjohnston@ashley-williams.com',
#    'phone': '762-368-3504x8972'},
#   {'supplier_name': 'Vega, Cook and Miller',
#    'contact_name': 'Stephen Rogers',
#    'email': 'ianderson@thompson.com',
#    'phone': '(545)747-7182x90685'},
#   {'supplier_name': 'Mendoza-Jones',
#    'contact_name': 'Daniel Archer',
#    'email': 'clarketodd@bush-parker.com',
#    'phone': '077.020.6783x0807'},
#   {'supplier_name': 'Gallagher-Miller',
#    'contact_name': 'Michael Moore',
#    'email': 'jesse95@gmail.com',
#    'phone': '+1-462-260-2525x67365'},
#   {'supplier_name': 'Miller-Martinez',
#    'contact_name': 'Paula Morales',
#    'email': 'floresderek@yahoo.com',
#    'phone': '+1-700-794-1809x5862'},
#   {'supplier_name': 'Freeman-Gordon',
#    'contact_name': 'Zachary Garcia',
#    'email': 'angela33@humphrey.org',
#    'phone': '172-492-5671'},
#   {'supplier_name': 'Tucker-Arnold',
#    'contact_name': 'Katherine Lopez DVM',
#    'email': 'michelle03@hotmail.com',
#    'phone': '001-661-335-2179x4217'},
#   {'supplier_name': 'Gomez PLC',
#    'contact_name': 'James Fernandez',
#    'email': 'lovewarren@harris.info',
#    'phone': '661-353-3289'},
#   {'supplier_name': 'Moss-Evans',
#    'contact_name': 'Jennifer Green',
#    'email': 'crystalroth@yahoo.com',
#    'phone': '+1-877-605-7924x7393'},
#   {'supplier_name': 'Charles Inc',
#    'contact_name': 'Lori Liu',
#    'email': 'suzanne20@donaldson.net',
#    'phone': '+1-059-663-9297x67941'},
#   {'supplier_name': 'Ortega-Mahoney',
#    'contact_name': 'Teresa Miller',
#    'email': 'ile@hotmail.com',
#    'phone': '001-415-849-5736x81908'},
#   {'supplier_name': 'Mann-Marshall',
#    'contact_name': 'Scott Watts',
#    'email': 'colejoseph@hotmail.com',
#    'phone': '7317296630'},
#   {'supplier_name': 'Hudson Inc',
#    'contact_name': 'Michael Nguyen',
#    'email': 'ucochran@osborn.com',
#    'phone': '+1-563-056-3764x85079'},
#   {'supplier_name': 'Douglas Ltd',
#    'contact_name': 'Jonathan White',
#    'email': 'michael15@hotmail.com',
#    'phone': '001-734-858-5527x84897'},
#   {'supplier_name': 'Barker, White and Carson',
#    'contact_name': 'Cesar Moore',
#    'email': 'qhogan@yahoo.com',
#    'phone': '(521)673-3153x7796'},
#   {'supplier_name': 'Barrett Ltd',
#    'contact_name': 'Kim Wheeler',
#    'email': 'william52@hotmail.com',
#    'phone': '+1-887-075-4700'},
#   {'supplier_name': 'Tran LLC',
#    'contact_name': 'Anthony Jacobs',
#    'email': 'bdavis@fuller.com',
#    'phone': '(460)711-5746'},
#   {'supplier_name': 'Franklin, Kane and Price',
#    'contact_name': 'John Mueller',
#    'email': 'mitchellpierce@gmail.com',
#    'phone': '230.183.6177x07682'},
#   {'supplier_name': 'Stewart, Williams and Cox',
#    'contact_name': 'Nichole Fuller',
#    'email': 'mitchelllauren@hotmail.com',
#    'phone': '001-632-585-1111x529'},
#   {'supplier_name': 'Johnson-Bass',
#    'contact_name': 'Megan Carroll',
#    'email': 'fernandeztiffany@page.net',
#    'phone': '3531846182'},
#   {'supplier_name': 'Lloyd and Sons',
#    'contact_name': 'Sarah Ross',
#    'email': 'heathkaren@gmail.com',
#    'phone': '064-804-0646x199'},
#   {'supplier_name': 'Taylor-Love',
#    'contact_name': 'Daniel Mcgrath',
#    'email': 'perrykeith@kennedy.com',
#    'phone': '841-905-8982x711'},
#   {'supplier_name': 'Elliott-Ayers',
#    'contact_name': 'Kelly Avery',
#    'email': 'joseph44@moore-soto.biz',
#    'phone': '768-127-8200x348'},
#   {'supplier_name': 'Reynolds-Phillips',
#    'contact_name': 'Ashlee Montoya',
#    'email': 'stonewesley@bowen-salinas.biz',
#    'phone': '+1-869-461-6007x4674'},
#   {'supplier_name': 'Moody-Vang',
#    'contact_name': 'Joseph Peterson',
#    'email': 'hward@hotmail.com',
#    'phone': '001-530-230-6560x82908'},
#   {'supplier_name': 'Perez, Price and Wallace',
#    'contact_name': 'James Rich',
#    'email': 'natashapierce@knox.com',
#    'phone': '409.569.6703'},
#   {'supplier_name': 'Wong Group',
#    'contact_name': 'Lauren Humphrey',
#    'email': 'hayeseric@george.com',
#    'phone': '546-100-3064x5276'},
#   {'supplier_name': 'Kaufman Ltd',
#    'contact_name': 'Chelsea Young',
#    'email': 'wendy80@smith.net',
#    'phone': '(434)045-1867x11846'},
#   {'supplier_name': 'Harris-Cummings',
#    'contact_name': 'Jonathan Foley',
#    'email': 'david30@hotmail.com',
#    'phone': '001-034-624-8811x93395'},
#   {'supplier_name': 'Turner-Davis',
#    'contact_name': 'Matthew Walker',
#    'email': 'wmurphy@mathis.org',
#    'phone': '579-218-9601x54220'},
#   {'supplier_name': 'Hall-Brown',
#    'contact_name': 'Richard Ballard',
#    'email': 'horneandrew@morgan.biz',
#    'phone': '+1-500-926-9681'},
#   {'supplier_name': 'Clark Group',
#    'contact_name': 'Stephen George DVM',
#    'email': 'royjessica@hotmail.com',
#    'phone': '(769)553-5373'},
#   {'supplier_name': 'Henderson LLC',
#    'contact_name': 'David Moore',
#    'email': 'benjamin57@yahoo.com',
#    'phone': '122.972.2988x83535'},
#   {'supplier_name': 'Rowe PLC',
#    'contact_name': 'Kevin Mcpherson',
#    'email': 'marco90@edwards-moran.com',
#    'phone': '496-064-5206x9241'},
#   {'supplier_name': 'Rogers-Greene',
#    'contact_name': 'Brady Brown',
#    'email': 'mcdowellkimberly@hotmail.com',
#    'phone': '883-297-7964x15108'},
#   {'supplier_name': 'Patrick, Walter and Harrison',
#    'contact_name': 'Mark Stevens',
#    'email': 'ymiller@hotmail.com',
#    'phone': '(561)464-9376x280'},
#   {'supplier_name': 'Williams Ltd',
#    'contact_name': 'Jeffery Allen',
#    'email': 'jcooper@kim-cook.org',
#    'phone': '316-798-3465x4653'},
#   {'supplier_name': 'Morgan-Andrews',
#    'contact_name': 'Cathy Marshall',
#    'email': 'fjohnson@gmail.com',
#    'phone': '088-233-7178x6223'},
#   {'supplier_name': 'Armstrong-Vance',
#    'contact_name': 'Regina Nicholson',
#    'email': 'jacobsonjohn@hotmail.com',
#    'phone': '+1-836-020-7265x14208'},
#   {'supplier_name': 'Morgan Inc',
#    'contact_name': 'Eric Farmer',
#    'email': 'pricejaclyn@jimenez.com',
#    'phone': '(672)354-2529x76848'},
#   {'supplier_name': 'Hensley-Branch',
#    'contact_name': 'Jordan Clark',
#    'email': 'alextucker@freeman.com',
#    'phone': '(120)216-0730x2946'}],
#  'Product With there Supplier and Current stock': [{'product_name': 'Ability Snack',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 755,
#    'reorder_level': 113},
#   {'product_name': 'Account Toy',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 758,
#    'reorder_level': 190},
#   {'product_name': 'Actually Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 300,
#    'reorder_level': 181},
#   {'product_name': 'After Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 590,
#    'reorder_level': 165},
#   {'product_name': 'Against Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'current_stock_quantity': 267,
#    'reorder_level': 161},
#   {'product_name': 'Alone Toy',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 691,
#    'reorder_level': 149},
#   {'product_name': 'Already Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 692,
#    'reorder_level': 60},
#   {'product_name': 'Among Toy',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 708,
#    'reorder_level': 117},
#   {'product_name': 'Amount Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 631,
#    'reorder_level': 98},
#   {'product_name': 'And Table',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 100,
#    'reorder_level': 99},
#   {'product_name': 'Another Device',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 357,
#    'reorder_level': 193},
#   {'product_name': 'Appear Toy',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 815,
#    'reorder_level': 138},
#   {'product_name': 'As Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 865,
#    'reorder_level': 120},
#   {'product_name': 'Ask Table',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 674,
#    'reorder_level': 97},
#   {'product_name': 'Audience Snack',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'current_stock_quantity': 467,
#    'reorder_level': 148},
#   {'product_name': 'Bag Table',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 545,
#    'reorder_level': 189},
#   {'product_name': 'Base Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 691,
#    'reorder_level': 178},
#   {'product_name': 'Base Toy',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 220,
#    'reorder_level': 61},
#   {'product_name': 'Become Device',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 633,
#    'reorder_level': 116},
#   {'product_name': 'Bed Toy',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 723,
#    'reorder_level': 140},
#   {'product_name': 'Between Shirt',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 107,
#    'reorder_level': 58},
#   {'product_name': 'Between Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 625,
#    'reorder_level': 190},
#   {'product_name': 'Billion Device',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 818,
#    'reorder_level': 138},
#   {'product_name': 'Blue Device',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 525,
#    'reorder_level': 54},
#   {'product_name': 'Book Device',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 46,
#    'reorder_level': 66},
#   {'product_name': 'Building Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_name': 'Certain Device',
#    'supplier_name': 'Gomez PLC',
#    'current_stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_name': 'Character Snack',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 629,
#    'reorder_level': 198},
#   {'product_name': 'Character Table',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 612,
#    'reorder_level': 187},
#   {'product_name': 'Check Snack',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 891,
#    'reorder_level': 93},
#   {'product_name': 'Choose Snack',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 406,
#    'reorder_level': 118},
#   {'product_name': 'Close Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_name': 'Coach Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 825,
#    'reorder_level': 124},
#   {'product_name': 'Conference Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 417,
#    'reorder_level': 96},
#   {'product_name': 'Could Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 628,
#    'reorder_level': 83},
#   {'product_name': 'Couple Shirt',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_name': 'Decade Shirt',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 219,
#    'reorder_level': 56},
#   {'product_name': 'Describe Toy',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 770,
#    'reorder_level': 83},
#   {'product_name': 'Determine Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 278,
#    'reorder_level': 144},
#   {'product_name': 'Discuss Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_name': 'Door Toy',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_name': 'During Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'current_stock_quantity': 967,
#    'reorder_level': 188},
#   {'product_name': 'Enter Table',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 512,
#    'reorder_level': 72},
#   {'product_name': 'Environment Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 667,
#    'reorder_level': 106},
#   {'product_name': 'Environmental Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 881,
#    'reorder_level': 93},
#   {'product_name': 'Everyone Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 332,
#    'reorder_level': 119},
#   {'product_name': 'Executive Table',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_name': 'Expert Snack',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 116,
#    'reorder_level': 98},
#   {'product_name': 'Fact Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 260,
#    'reorder_level': 174},
#   {'product_name': 'Fast Shirt',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 863,
#    'reorder_level': 105},
#   {'product_name': 'Feeling Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 441,
#    'reorder_level': 71},
#   {'product_name': 'Final Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 976,
#    'reorder_level': 98},
#   {'product_name': 'Floor Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 460,
#    'reorder_level': 105},
#   {'product_name': 'Floor Toy',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_name': 'Foreign Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 959,
#    'reorder_level': 86},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 778,
#    'reorder_level': 173},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 939,
#    'reorder_level': 102},
#   {'product_name': 'Four Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_name': 'From Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 247,
#    'reorder_level': 149},
#   {'product_name': 'Full Table',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 591,
#    'reorder_level': 122},
#   {'product_name': 'Fund Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_name': 'Gas Snack',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 337,
#    'reorder_level': 93},
#   {'product_name': 'Give Shirt',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 240,
#    'reorder_level': 61},
#   {'product_name': 'Give Snack',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Ground Device',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 533,
#    'reorder_level': 116},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 360,
#    'reorder_level': 67},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 257,
#    'reorder_level': 87},
#   {'product_name': 'Gun Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 556,
#    'reorder_level': 134},
#   {'product_name': 'Guy Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 274,
#    'reorder_level': 93},
#   {'product_name': 'Hand Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 233,
#    'reorder_level': 82},
#   {'product_name': 'Hard Snack',
#    'supplier_name': 'Evans Inc',
#    'current_stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_name': 'Help Snack',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 357,
#    'reorder_level': 142},
#   {'product_name': 'Himself Toy',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 347,
#    'reorder_level': 105},
#   {'product_name': 'Hold Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 695,
#    'reorder_level': 155},
#   {'product_name': 'Hospital Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 444,
#    'reorder_level': 120},
#   {'product_name': 'However Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 707,
#    'reorder_level': 95},
#   {'product_name': 'However Table',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_name': 'If Table',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 393,
#    'reorder_level': 50},
#   {'product_name': 'Improve Snack',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 869,
#    'reorder_level': 181},
#   {'product_name': 'Include Device',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 856,
#    'reorder_level': 55},
#   {'product_name': 'Information Snack',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 708,
#    'reorder_level': 65},
#   {'product_name': 'Instead Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 231,
#    'reorder_level': 51},
#   {'product_name': 'Instead Table',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 620,
#    'reorder_level': 99},
#   {'product_name': 'Investment Toy',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 834,
#    'reorder_level': 142},
#   {'product_name': 'Issue Device',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 412,
#    'reorder_level': 189},
#   {'product_name': 'Itself Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 133,
#    'reorder_level': 125},
#   {'product_name': 'Job Snack',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 447,
#    'reorder_level': 120},
#   {'product_name': 'Just Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 847,
#    'reorder_level': 114},
#   {'product_name': 'laptop',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 90,
#    'reorder_level': 25},
#   {'product_name': 'Later Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'current_stock_quantity': 121,
#    'reorder_level': 61},
#   {'product_name': 'Law Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 485,
#    'reorder_level': 70},
#   {'product_name': 'Law Shirt',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 675,
#    'reorder_level': 126},
#   {'product_name': 'Law Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 931,
#    'reorder_level': 90},
#   {'product_name': 'Lead Toy',
#    'supplier_name': 'Gomez PLC',
#    'current_stock_quantity': 921,
#    'reorder_level': 156},
#   {'product_name': 'Least Table',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_name': 'Leave Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 521,
#    'reorder_level': 173},
#   {'product_name': 'Like Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 334,
#    'reorder_level': 131},
#   {'product_name': 'Local Shirt',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 749,
#    'reorder_level': 110},
#   {'product_name': 'Local Snack',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 861,
#    'reorder_level': 72},
#   {'product_name': 'Lose Toy',
#    'supplier_name': 'Mendoza-Jones',
#    'current_stock_quantity': 127,
#    'reorder_level': 92},
#   {'product_name': 'Manage Snack',
#    'supplier_name': 'Armstrong-Vance',
#    'current_stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_name': 'Manage Table',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 328,
#    'reorder_level': 158},
#   {'product_name': 'Material Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 451,
#    'reorder_level': 145},
#   {'product_name': 'Meet Shirt',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 892,
#    'reorder_level': 76},
#   {'product_name': 'Meeting Shirt',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 642,
#    'reorder_level': 143},
#   {'product_name': 'Member Toy',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 516,
#    'reorder_level': 53},
#   {'product_name': 'Military Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 411,
#    'reorder_level': 110},
#   {'product_name': 'Mission Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 893,
#    'reorder_level': 59},
#   {'product_name': 'Most Shirt',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 560,
#    'reorder_level': 93},
#   {'product_name': 'Mouth Shirt',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 502,
#    'reorder_level': 99},
#   {'product_name': 'Movie Snack',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 979,
#    'reorder_level': 131},
#   {'product_name': 'Mr Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 944,
#    'reorder_level': 179},
#   {'product_name': 'National Shirt',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 394,
#    'reorder_level': 198},
#   {'product_name': 'Necessary Device',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 298,
#    'reorder_level': 193},
#   {'product_name': 'Next Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_name': 'Nor Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_name': 'North Shirt',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 644,
#    'reorder_level': 152},
#   {'product_name': 'Nothing Snack',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 375,
#    'reorder_level': 81},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Evans Inc',
#    'current_stock_quantity': 640,
#    'reorder_level': 113},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 866,
#    'reorder_level': 60},
#   {'product_name': 'Old Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 996,
#    'reorder_level': 130},
#   {'product_name': 'Onto Shirt',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 98,
#    'reorder_level': 62},
#   {'product_name': 'Paper Toy',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 212,
#    'reorder_level': 101},
#   {'product_name': 'Part Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 652,
#    'reorder_level': 88},
#   {'product_name': 'Personal Table',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 962,
#    'reorder_level': 59},
#   {'product_name': 'Phone Shirt',
#    'supplier_name': 'Armstrong-Vance',
#    'current_stock_quantity': 97,
#    'reorder_level': 91},
#   {'product_name': 'Piece Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 536,
#    'reorder_level': 191},
#   {'product_name': 'Player Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 530,
#    'reorder_level': 132},
#   {'product_name': 'Poor Snack',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Race Device',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_name': 'Reach Device',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 623,
#    'reorder_level': 179},
#   {'product_name': 'Real Snack',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_name': 'Reality Table',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 804,
#    'reorder_level': 54},
#   {'product_name': 'Really Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 424,
#    'reorder_level': 160},
#   {'product_name': 'Region Toy',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 488,
#    'reorder_level': 68},
#   {'product_name': 'Report Toy',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 575,
#    'reorder_level': 166},
#   {'product_name': 'Require Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 987,
#    'reorder_level': 102},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 177,
#    'reorder_level': 75},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_name': 'Run Device',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 341,
#    'reorder_level': 111},
#   {'product_name': 'Scene Table',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 645,
#    'reorder_level': 74},
#   {'product_name': 'School Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 687,
#    'reorder_level': 100},
#   {'product_name': 'Scientist Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'current_stock_quantity': 902,
#    'reorder_level': 114},
#   {'product_name': 'Security Shirt',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'current_stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_name': 'Sense Snack',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 675,
#    'reorder_level': 161},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Clark Group',
#    'current_stock_quantity': 649,
#    'reorder_level': 114},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'current_stock_quantity': 856,
#    'reorder_level': 120},
#   {'product_name': 'Several Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 652,
#    'reorder_level': 199},
#   {'product_name': 'Sign Toy',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 768,
#    'reorder_level': 169},
#   {'product_name': 'Simple Device',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 888,
#    'reorder_level': 77},
#   {'product_name': 'Since Shirt',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 304,
#    'reorder_level': 155},
#   {'product_name': 'Sit Toy',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 474,
#    'reorder_level': 121},
#   {'product_name': 'Six Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 493,
#    'reorder_level': 100},
#   {'product_name': 'Six Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 442,
#    'reorder_level': 76},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'So Table',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 723,
#    'reorder_level': 60},
#   {'product_name': 'Someone Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 801,
#    'reorder_level': 105},
#   {'product_name': 'Sound Snack',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 89,
#    'reorder_level': 59},
#   {'product_name': 'Sound Table',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 256,
#    'reorder_level': 84},
#   {'product_name': 'South Device',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 742,
#    'reorder_level': 196},
#   {'product_name': 'Space Toy',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 693,
#    'reorder_level': 126},
#   {'product_name': 'Speak Shirt',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 540,
#    'reorder_level': 80},
#   {'product_name': 'Spring Toy',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 336,
#    'reorder_level': 199},
#   {'product_name': 'Staff Shirt',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_name': 'Start Table',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 865,
#    'reorder_level': 147},
#   {'product_name': 'Still Snack',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 433,
#    'reorder_level': 178},
#   {'product_name': 'Store Toy',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 874,
#    'reorder_level': 50},
#   {'product_name': 'Story Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 510,
#    'reorder_level': 116},
#   {'product_name': 'Suddenly Device',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 372,
#    'reorder_level': 183},
#   {'product_name': 'Suddenly Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_name': 'Summer Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 320,
#    'reorder_level': 96},
#   {'product_name': 'Sure Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 309,
#    'reorder_level': 125},
#   {'product_name': 'Surface Shirt',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 530,
#    'reorder_level': 137},
#   {'product_name': 'System Snack',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 503,
#    'reorder_level': 138},
#   {'product_name': 'Tax Device',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 644,
#    'reorder_level': 84},
#   {'product_name': 'Teacher Toy',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 436,
#    'reorder_level': 189},
#   {'product_name': 'Thank Shirt',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 902,
#    'reorder_level': 83},
#   {'product_name': 'These Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 998,
#    'reorder_level': 163},
#   {'product_name': 'This Snack',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 936,
#    'reorder_level': 133},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 451,
#    'reorder_level': 57},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 248,
#    'reorder_level': 118},
#   {'product_name': 'Throughout Toy',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 192,
#    'reorder_level': 118},
#   {'product_name': 'Throw Device',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 862,
#    'reorder_level': 191},
#   {'product_name': 'Throw Toy',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_name': 'Tough Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 660,
#    'reorder_level': 154},
#   {'product_name': 'Town Toy',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 376,
#    'reorder_level': 182},
#   {'product_name': 'Treat Device',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 122,
#    'reorder_level': 89},
#   {'product_name': 'Trouble Table',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 826,
#    'reorder_level': 166},
#   {'product_name': 'True Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 741,
#    'reorder_level': 200},
#   {'product_name': 'Truth Device',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 570,
#    'reorder_level': 78},
#   {'product_name': 'Value Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 480,
#    'reorder_level': 199},
#   {'product_name': 'Wait Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 164,
#    'reorder_level': 164},
#   {'product_name': 'Way Snack',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 725,
#    'reorder_level': 77},
#   {'product_name': 'Where Toy',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 848,
#    'reorder_level': 80},
#   {'product_name': 'White Table',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 702,
#    'reorder_level': 143},
#   {'product_name': 'Whom Table',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 727,
#    'reorder_level': 186},
#   {'product_name': 'Whose Snack',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 182,
#    'reorder_level': 177},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 839,
#    'reorder_level': 193},
#   {'product_name': 'Writer Table',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 700,
#    'reorder_level': 198}],
#  'Product needing Reorder': [{'product_id': 19,
#    'product_name': 'Next Device',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_id': 36,
#    'product_name': 'Race Device',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_id': 46,
#    'product_name': 'Close Toy',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_id': 50,
#    'product_name': 'Hard Snack',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_id': 51,
#    'product_name': 'Staff Shirt',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_id': 58,
#    'product_name': 'Floor Toy',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_id': 62,
#    'product_name': 'Throw Toy',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_id': 100,
#    'product_name': 'Fund Table',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_id': 108,
#    'product_name': 'Executive Table',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_id': 110,
#    'product_name': 'However Table',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_id': 113,
#    'product_name': 'Certain Device',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_id': 132,
#    'product_name': 'This Snack',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_id': 136,
#    'product_name': 'Within Toy',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_id': 137,
#    'product_name': 'Least Table',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_id': 144,
#    'product_name': 'Building Snack',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_id': 150,
#    'product_name': 'Return Table',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_id': 153,
#    'product_name': 'Security Shirt',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_id': 154,
#    'product_name': 'Manage Snack',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_id': 160,
#    'product_name': 'Suddenly Table',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_id': 165,
#    'product_name': 'Nor Snack',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_id': 167,
#    'product_name': 'Discuss Toy',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_id': 169,
#    'product_name': 'Four Shirt',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_id': 173,
#    'product_name': 'Real Snack',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_id': 180,
#    'product_name': 'Door Toy',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_id': 185,
#    'product_name': 'Couple Shirt',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_id': 192,
#    'product_name': 'Thought Toy',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_id': 199,
#    'product_name': 'Book Device',
#    'stock_quantity': 46,
#    'reorder_level': 66}]}

# %%
def additional_info(cursor):
    queries = {
         "supplier contact details":
    
    """SELECT supplier_name,contact_name,email,phone  FROM suppliers;""",
    
    "Product With there Supplier and Current stock":"""SELECT product_name,supplier_name,stock_quantity as current_stock_quantity,reorder_level   FROM suppliers t1
    JOIN products t2
    ON t1.supplier_id = t2.supplier_id
    ORDER BY product_name;
    """,
    
    "Product needing Reorder":"""SELECT product_id,product_name,stock_quantity,reorder_level from products 
    WHERE stock_quantity<reorder_level;"""
    
    
    }

    result = {}
    for label,querie in queries.items():
        cursor.execute(querie)
        row = cursor.fetchall()
        result[label]=row

    return result

# %%
additional_info(cursor)
# Out:
# {'supplier contact details': [{'supplier_name': 'Anderson-Thompson',
#    'contact_name': 'Bonnie Davis',
#    'email': 'zacharysanchez@hotmail.com',
#    'phone': '829.485.9853x0522'},
#   {'supplier_name': 'Rowland Ltd',
#    'contact_name': 'Beth Stevens',
#    'email': 'joshua60@yahoo.com',
#    'phone': '(779)942-0726'},
#   {'supplier_name': 'Baxter-Meadows',
#    'contact_name': 'Lisa Lewis',
#    'email': 'andersonchristina@yahoo.com',
#    'phone': '449-766-7325'},
#   {'supplier_name': 'Wilson, Graham and Williams',
#    'contact_name': 'David Martinez',
#    'email': 'abrown@hotmail.com',
#    'phone': '+1-653-827-5215x266'},
#   {'supplier_name': 'Smith, Kennedy and Moreno',
#    'contact_name': 'Victoria Gonzalez',
#    'email': 'mary30@williams-moore.com',
#    'phone': '891-859-2775x35297'},
#   {'supplier_name': 'Middleton LLC',
#    'contact_name': 'Megan Miller',
#    'email': 'kelseywilliams@gmail.com',
#    'phone': '001-724-731-6199x4596'},
#   {'supplier_name': 'Evans Inc',
#    'contact_name': 'Danielle Moore',
#    'email': 'ihoffman@warren.com',
#    'phone': '+1-951-447-1975x770'},
#   {'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'contact_name': 'Tamara Johnson',
#    'email': 'georgeherrera@hotmail.com',
#    'phone': '+1-635-460-8476x270'},
#   {'supplier_name': 'Young, Browning and Ware',
#    'contact_name': 'Heather Hill',
#    'email': 'stephensjason@yahoo.com',
#    'phone': '(514)361-6411x489'},
#   {'supplier_name': 'Newton, Valencia and Carr',
#    'contact_name': 'Kimberly Collins',
#    'email': 'jonathanjohnston@ashley-williams.com',
#    'phone': '762-368-3504x8972'},
#   {'supplier_name': 'Vega, Cook and Miller',
#    'contact_name': 'Stephen Rogers',
#    'email': 'ianderson@thompson.com',
#    'phone': '(545)747-7182x90685'},
#   {'supplier_name': 'Mendoza-Jones',
#    'contact_name': 'Daniel Archer',
#    'email': 'clarketodd@bush-parker.com',
#    'phone': '077.020.6783x0807'},
#   {'supplier_name': 'Gallagher-Miller',
#    'contact_name': 'Michael Moore',
#    'email': 'jesse95@gmail.com',
#    'phone': '+1-462-260-2525x67365'},
#   {'supplier_name': 'Miller-Martinez',
#    'contact_name': 'Paula Morales',
#    'email': 'floresderek@yahoo.com',
#    'phone': '+1-700-794-1809x5862'},
#   {'supplier_name': 'Freeman-Gordon',
#    'contact_name': 'Zachary Garcia',
#    'email': 'angela33@humphrey.org',
#    'phone': '172-492-5671'},
#   {'supplier_name': 'Tucker-Arnold',
#    'contact_name': 'Katherine Lopez DVM',
#    'email': 'michelle03@hotmail.com',
#    'phone': '001-661-335-2179x4217'},
#   {'supplier_name': 'Gomez PLC',
#    'contact_name': 'James Fernandez',
#    'email': 'lovewarren@harris.info',
#    'phone': '661-353-3289'},
#   {'supplier_name': 'Moss-Evans',
#    'contact_name': 'Jennifer Green',
#    'email': 'crystalroth@yahoo.com',
#    'phone': '+1-877-605-7924x7393'},
#   {'supplier_name': 'Charles Inc',
#    'contact_name': 'Lori Liu',
#    'email': 'suzanne20@donaldson.net',
#    'phone': '+1-059-663-9297x67941'},
#   {'supplier_name': 'Ortega-Mahoney',
#    'contact_name': 'Teresa Miller',
#    'email': 'ile@hotmail.com',
#    'phone': '001-415-849-5736x81908'},
#   {'supplier_name': 'Mann-Marshall',
#    'contact_name': 'Scott Watts',
#    'email': 'colejoseph@hotmail.com',
#    'phone': '7317296630'},
#   {'supplier_name': 'Hudson Inc',
#    'contact_name': 'Michael Nguyen',
#    'email': 'ucochran@osborn.com',
#    'phone': '+1-563-056-3764x85079'},
#   {'supplier_name': 'Douglas Ltd',
#    'contact_name': 'Jonathan White',
#    'email': 'michael15@hotmail.com',
#    'phone': '001-734-858-5527x84897'},
#   {'supplier_name': 'Barker, White and Carson',
#    'contact_name': 'Cesar Moore',
#    'email': 'qhogan@yahoo.com',
#    'phone': '(521)673-3153x7796'},
#   {'supplier_name': 'Barrett Ltd',
#    'contact_name': 'Kim Wheeler',
#    'email': 'william52@hotmail.com',
#    'phone': '+1-887-075-4700'},
#   {'supplier_name': 'Tran LLC',
#    'contact_name': 'Anthony Jacobs',
#    'email': 'bdavis@fuller.com',
#    'phone': '(460)711-5746'},
#   {'supplier_name': 'Franklin, Kane and Price',
#    'contact_name': 'John Mueller',
#    'email': 'mitchellpierce@gmail.com',
#    'phone': '230.183.6177x07682'},
#   {'supplier_name': 'Stewart, Williams and Cox',
#    'contact_name': 'Nichole Fuller',
#    'email': 'mitchelllauren@hotmail.com',
#    'phone': '001-632-585-1111x529'},
#   {'supplier_name': 'Johnson-Bass',
#    'contact_name': 'Megan Carroll',
#    'email': 'fernandeztiffany@page.net',
#    'phone': '3531846182'},
#   {'supplier_name': 'Lloyd and Sons',
#    'contact_name': 'Sarah Ross',
#    'email': 'heathkaren@gmail.com',
#    'phone': '064-804-0646x199'},
#   {'supplier_name': 'Taylor-Love',
#    'contact_name': 'Daniel Mcgrath',
#    'email': 'perrykeith@kennedy.com',
#    'phone': '841-905-8982x711'},
#   {'supplier_name': 'Elliott-Ayers',
#    'contact_name': 'Kelly Avery',
#    'email': 'joseph44@moore-soto.biz',
#    'phone': '768-127-8200x348'},
#   {'supplier_name': 'Reynolds-Phillips',
#    'contact_name': 'Ashlee Montoya',
#    'email': 'stonewesley@bowen-salinas.biz',
#    'phone': '+1-869-461-6007x4674'},
#   {'supplier_name': 'Moody-Vang',
#    'contact_name': 'Joseph Peterson',
#    'email': 'hward@hotmail.com',
#    'phone': '001-530-230-6560x82908'},
#   {'supplier_name': 'Perez, Price and Wallace',
#    'contact_name': 'James Rich',
#    'email': 'natashapierce@knox.com',
#    'phone': '409.569.6703'},
#   {'supplier_name': 'Wong Group',
#    'contact_name': 'Lauren Humphrey',
#    'email': 'hayeseric@george.com',
#    'phone': '546-100-3064x5276'},
#   {'supplier_name': 'Kaufman Ltd',
#    'contact_name': 'Chelsea Young',
#    'email': 'wendy80@smith.net',
#    'phone': '(434)045-1867x11846'},
#   {'supplier_name': 'Harris-Cummings',
#    'contact_name': 'Jonathan Foley',
#    'email': 'david30@hotmail.com',
#    'phone': '001-034-624-8811x93395'},
#   {'supplier_name': 'Turner-Davis',
#    'contact_name': 'Matthew Walker',
#    'email': 'wmurphy@mathis.org',
#    'phone': '579-218-9601x54220'},
#   {'supplier_name': 'Hall-Brown',
#    'contact_name': 'Richard Ballard',
#    'email': 'horneandrew@morgan.biz',
#    'phone': '+1-500-926-9681'},
#   {'supplier_name': 'Clark Group',
#    'contact_name': 'Stephen George DVM',
#    'email': 'royjessica@hotmail.com',
#    'phone': '(769)553-5373'},
#   {'supplier_name': 'Henderson LLC',
#    'contact_name': 'David Moore',
#    'email': 'benjamin57@yahoo.com',
#    'phone': '122.972.2988x83535'},
#   {'supplier_name': 'Rowe PLC',
#    'contact_name': 'Kevin Mcpherson',
#    'email': 'marco90@edwards-moran.com',
#    'phone': '496-064-5206x9241'},
#   {'supplier_name': 'Rogers-Greene',
#    'contact_name': 'Brady Brown',
#    'email': 'mcdowellkimberly@hotmail.com',
#    'phone': '883-297-7964x15108'},
#   {'supplier_name': 'Patrick, Walter and Harrison',
#    'contact_name': 'Mark Stevens',
#    'email': 'ymiller@hotmail.com',
#    'phone': '(561)464-9376x280'},
#   {'supplier_name': 'Williams Ltd',
#    'contact_name': 'Jeffery Allen',
#    'email': 'jcooper@kim-cook.org',
#    'phone': '316-798-3465x4653'},
#   {'supplier_name': 'Morgan-Andrews',
#    'contact_name': 'Cathy Marshall',
#    'email': 'fjohnson@gmail.com',
#    'phone': '088-233-7178x6223'},
#   {'supplier_name': 'Armstrong-Vance',
#    'contact_name': 'Regina Nicholson',
#    'email': 'jacobsonjohn@hotmail.com',
#    'phone': '+1-836-020-7265x14208'},
#   {'supplier_name': 'Morgan Inc',
#    'contact_name': 'Eric Farmer',
#    'email': 'pricejaclyn@jimenez.com',
#    'phone': '(672)354-2529x76848'},
#   {'supplier_name': 'Hensley-Branch',
#    'contact_name': 'Jordan Clark',
#    'email': 'alextucker@freeman.com',
#    'phone': '(120)216-0730x2946'}],
#  'Product With there Supplier and Current stock': [{'product_name': 'Ability Snack',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 755,
#    'reorder_level': 113},
#   {'product_name': 'Account Toy',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 758,
#    'reorder_level': 190},
#   {'product_name': 'Actually Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 300,
#    'reorder_level': 181},
#   {'product_name': 'After Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 590,
#    'reorder_level': 165},
#   {'product_name': 'Against Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'current_stock_quantity': 267,
#    'reorder_level': 161},
#   {'product_name': 'Alone Toy',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 691,
#    'reorder_level': 149},
#   {'product_name': 'Already Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 692,
#    'reorder_level': 60},
#   {'product_name': 'Among Toy',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 708,
#    'reorder_level': 117},
#   {'product_name': 'Amount Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 631,
#    'reorder_level': 98},
#   {'product_name': 'And Table',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 100,
#    'reorder_level': 99},
#   {'product_name': 'Another Device',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 357,
#    'reorder_level': 193},
#   {'product_name': 'Appear Toy',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 815,
#    'reorder_level': 138},
#   {'product_name': 'As Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 865,
#    'reorder_level': 120},
#   {'product_name': 'Ask Table',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 674,
#    'reorder_level': 97},
#   {'product_name': 'Audience Snack',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'current_stock_quantity': 467,
#    'reorder_level': 148},
#   {'product_name': 'Bag Table',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 545,
#    'reorder_level': 189},
#   {'product_name': 'Base Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 691,
#    'reorder_level': 178},
#   {'product_name': 'Base Toy',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 220,
#    'reorder_level': 61},
#   {'product_name': 'Become Device',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 633,
#    'reorder_level': 116},
#   {'product_name': 'Bed Toy',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 723,
#    'reorder_level': 140},
#   {'product_name': 'Between Shirt',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 107,
#    'reorder_level': 58},
#   {'product_name': 'Between Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 625,
#    'reorder_level': 190},
#   {'product_name': 'Billion Device',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 818,
#    'reorder_level': 138},
#   {'product_name': 'Blue Device',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 525,
#    'reorder_level': 54},
#   {'product_name': 'Book Device',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 46,
#    'reorder_level': 66},
#   {'product_name': 'Building Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_name': 'Certain Device',
#    'supplier_name': 'Gomez PLC',
#    'current_stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_name': 'Character Snack',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 629,
#    'reorder_level': 198},
#   {'product_name': 'Character Table',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 612,
#    'reorder_level': 187},
#   {'product_name': 'Check Snack',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 891,
#    'reorder_level': 93},
#   {'product_name': 'Choose Snack',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 406,
#    'reorder_level': 118},
#   {'product_name': 'Close Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_name': 'Coach Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 825,
#    'reorder_level': 124},
#   {'product_name': 'Conference Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 417,
#    'reorder_level': 96},
#   {'product_name': 'Could Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 628,
#    'reorder_level': 83},
#   {'product_name': 'Couple Shirt',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_name': 'Decade Shirt',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 219,
#    'reorder_level': 56},
#   {'product_name': 'Describe Toy',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 770,
#    'reorder_level': 83},
#   {'product_name': 'Determine Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 278,
#    'reorder_level': 144},
#   {'product_name': 'Discuss Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_name': 'Door Toy',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_name': 'During Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'current_stock_quantity': 967,
#    'reorder_level': 188},
#   {'product_name': 'Enter Table',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 512,
#    'reorder_level': 72},
#   {'product_name': 'Environment Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 667,
#    'reorder_level': 106},
#   {'product_name': 'Environmental Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 881,
#    'reorder_level': 93},
#   {'product_name': 'Everyone Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 332,
#    'reorder_level': 119},
#   {'product_name': 'Executive Table',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_name': 'Expert Snack',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 116,
#    'reorder_level': 98},
#   {'product_name': 'Fact Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 260,
#    'reorder_level': 174},
#   {'product_name': 'Fast Shirt',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 863,
#    'reorder_level': 105},
#   {'product_name': 'Feeling Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 441,
#    'reorder_level': 71},
#   {'product_name': 'Final Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 976,
#    'reorder_level': 98},
#   {'product_name': 'Floor Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 460,
#    'reorder_level': 105},
#   {'product_name': 'Floor Toy',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_name': 'Foreign Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 959,
#    'reorder_level': 86},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 778,
#    'reorder_level': 173},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 939,
#    'reorder_level': 102},
#   {'product_name': 'Four Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_name': 'From Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'current_stock_quantity': 247,
#    'reorder_level': 149},
#   {'product_name': 'Full Table',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 591,
#    'reorder_level': 122},
#   {'product_name': 'Fund Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_name': 'Gas Snack',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 337,
#    'reorder_level': 93},
#   {'product_name': 'Give Shirt',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 240,
#    'reorder_level': 61},
#   {'product_name': 'Give Snack',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Ground Device',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 533,
#    'reorder_level': 116},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 360,
#    'reorder_level': 67},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 257,
#    'reorder_level': 87},
#   {'product_name': 'Gun Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 556,
#    'reorder_level': 134},
#   {'product_name': 'Guy Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 274,
#    'reorder_level': 93},
#   {'product_name': 'Hand Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 233,
#    'reorder_level': 82},
#   {'product_name': 'Hard Snack',
#    'supplier_name': 'Evans Inc',
#    'current_stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_name': 'Help Snack',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 357,
#    'reorder_level': 142},
#   {'product_name': 'Himself Toy',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 347,
#    'reorder_level': 105},
#   {'product_name': 'Hold Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 695,
#    'reorder_level': 155},
#   {'product_name': 'Hospital Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 444,
#    'reorder_level': 120},
#   {'product_name': 'However Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 707,
#    'reorder_level': 95},
#   {'product_name': 'However Table',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_name': 'If Table',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 393,
#    'reorder_level': 50},
#   {'product_name': 'Improve Snack',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 869,
#    'reorder_level': 181},
#   {'product_name': 'Include Device',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 856,
#    'reorder_level': 55},
#   {'product_name': 'Information Snack',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 708,
#    'reorder_level': 65},
#   {'product_name': 'Instead Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 231,
#    'reorder_level': 51},
#   {'product_name': 'Instead Table',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 620,
#    'reorder_level': 99},
#   {'product_name': 'Investment Toy',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 834,
#    'reorder_level': 142},
#   {'product_name': 'Issue Device',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 412,
#    'reorder_level': 189},
#   {'product_name': 'Itself Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 133,
#    'reorder_level': 125},
#   {'product_name': 'Job Snack',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 447,
#    'reorder_level': 120},
#   {'product_name': 'Just Device',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 847,
#    'reorder_level': 114},
#   {'product_name': 'laptop',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 90,
#    'reorder_level': 25},
#   {'product_name': 'Later Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'current_stock_quantity': 121,
#    'reorder_level': 61},
#   {'product_name': 'Law Device',
#    'supplier_name': 'Kaufman Ltd',
#    'current_stock_quantity': 485,
#    'reorder_level': 70},
#   {'product_name': 'Law Shirt',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 675,
#    'reorder_level': 126},
#   {'product_name': 'Law Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 931,
#    'reorder_level': 90},
#   {'product_name': 'Lead Toy',
#    'supplier_name': 'Gomez PLC',
#    'current_stock_quantity': 921,
#    'reorder_level': 156},
#   {'product_name': 'Least Table',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_name': 'Leave Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 521,
#    'reorder_level': 173},
#   {'product_name': 'Like Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 334,
#    'reorder_level': 131},
#   {'product_name': 'Local Shirt',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 749,
#    'reorder_level': 110},
#   {'product_name': 'Local Snack',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 861,
#    'reorder_level': 72},
#   {'product_name': 'Lose Toy',
#    'supplier_name': 'Mendoza-Jones',
#    'current_stock_quantity': 127,
#    'reorder_level': 92},
#   {'product_name': 'Manage Snack',
#    'supplier_name': 'Armstrong-Vance',
#    'current_stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_name': 'Manage Table',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 328,
#    'reorder_level': 158},
#   {'product_name': 'Material Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 451,
#    'reorder_level': 145},
#   {'product_name': 'Meet Shirt',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 892,
#    'reorder_level': 76},
#   {'product_name': 'Meeting Shirt',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 642,
#    'reorder_level': 143},
#   {'product_name': 'Member Toy',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 516,
#    'reorder_level': 53},
#   {'product_name': 'Military Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 411,
#    'reorder_level': 110},
#   {'product_name': 'Mission Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 893,
#    'reorder_level': 59},
#   {'product_name': 'Most Shirt',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 560,
#    'reorder_level': 93},
#   {'product_name': 'Mouth Shirt',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 502,
#    'reorder_level': 99},
#   {'product_name': 'Movie Snack',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 979,
#    'reorder_level': 131},
#   {'product_name': 'Mr Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 944,
#    'reorder_level': 179},
#   {'product_name': 'National Shirt',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 394,
#    'reorder_level': 198},
#   {'product_name': 'Necessary Device',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 298,
#    'reorder_level': 193},
#   {'product_name': 'Next Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_name': 'Nor Snack',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_name': 'North Shirt',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 644,
#    'reorder_level': 152},
#   {'product_name': 'Nothing Snack',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 375,
#    'reorder_level': 81},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Evans Inc',
#    'current_stock_quantity': 640,
#    'reorder_level': 113},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 866,
#    'reorder_level': 60},
#   {'product_name': 'Old Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'current_stock_quantity': 996,
#    'reorder_level': 130},
#   {'product_name': 'Onto Shirt',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 98,
#    'reorder_level': 62},
#   {'product_name': 'Paper Toy',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 212,
#    'reorder_level': 101},
#   {'product_name': 'Part Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 652,
#    'reorder_level': 88},
#   {'product_name': 'Personal Table',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 962,
#    'reorder_level': 59},
#   {'product_name': 'Phone Shirt',
#    'supplier_name': 'Armstrong-Vance',
#    'current_stock_quantity': 97,
#    'reorder_level': 91},
#   {'product_name': 'Piece Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 536,
#    'reorder_level': 191},
#   {'product_name': 'Player Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'current_stock_quantity': 530,
#    'reorder_level': 132},
#   {'product_name': 'Poor Snack',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Race Device',
#    'supplier_name': 'Baxter-Meadows',
#    'current_stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_name': 'Reach Device',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 623,
#    'reorder_level': 179},
#   {'product_name': 'Real Snack',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_name': 'Reality Table',
#    'supplier_name': 'Rowe PLC',
#    'current_stock_quantity': 804,
#    'reorder_level': 54},
#   {'product_name': 'Really Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 424,
#    'reorder_level': 160},
#   {'product_name': 'Region Toy',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 488,
#    'reorder_level': 68},
#   {'product_name': 'Report Toy',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 575,
#    'reorder_level': 166},
#   {'product_name': 'Require Toy',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 987,
#    'reorder_level': 102},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 177,
#    'reorder_level': 75},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_name': 'Run Device',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 341,
#    'reorder_level': 111},
#   {'product_name': 'Scene Table',
#    'supplier_name': 'Freeman-Gordon',
#    'current_stock_quantity': 645,
#    'reorder_level': 74},
#   {'product_name': 'School Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 687,
#    'reorder_level': 100},
#   {'product_name': 'Scientist Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'current_stock_quantity': 902,
#    'reorder_level': 114},
#   {'product_name': 'Security Shirt',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'current_stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_name': 'Sense Snack',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 675,
#    'reorder_level': 161},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Clark Group',
#    'current_stock_quantity': 649,
#    'reorder_level': 114},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'current_stock_quantity': 856,
#    'reorder_level': 120},
#   {'product_name': 'Several Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 652,
#    'reorder_level': 199},
#   {'product_name': 'Sign Toy',
#    'supplier_name': 'Charles Inc',
#    'current_stock_quantity': 768,
#    'reorder_level': 169},
#   {'product_name': 'Simple Device',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 888,
#    'reorder_level': 77},
#   {'product_name': 'Since Shirt',
#    'supplier_name': 'Turner-Davis',
#    'current_stock_quantity': 304,
#    'reorder_level': 155},
#   {'product_name': 'Sit Toy',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 474,
#    'reorder_level': 121},
#   {'product_name': 'Six Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 493,
#    'reorder_level': 100},
#   {'product_name': 'Six Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 442,
#    'reorder_level': 76},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'smart watch',
#    'supplier_name': 'Ortega-Mahoney',
#    'current_stock_quantity': 900,
#    'reorder_level': 500},
#   {'product_name': 'So Table',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 723,
#    'reorder_level': 60},
#   {'product_name': 'Someone Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 801,
#    'reorder_level': 105},
#   {'product_name': 'Sound Snack',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 89,
#    'reorder_level': 59},
#   {'product_name': 'Sound Table',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 256,
#    'reorder_level': 84},
#   {'product_name': 'South Device',
#    'supplier_name': 'Hensley-Branch',
#    'current_stock_quantity': 742,
#    'reorder_level': 196},
#   {'product_name': 'Space Toy',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 693,
#    'reorder_level': 126},
#   {'product_name': 'Speak Shirt',
#    'supplier_name': 'Middleton LLC',
#    'current_stock_quantity': 540,
#    'reorder_level': 80},
#   {'product_name': 'Spring Toy',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 336,
#    'reorder_level': 199},
#   {'product_name': 'Staff Shirt',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_name': 'Start Table',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 865,
#    'reorder_level': 147},
#   {'product_name': 'Still Snack',
#    'supplier_name': 'Rowland Ltd',
#    'current_stock_quantity': 433,
#    'reorder_level': 178},
#   {'product_name': 'Store Toy',
#    'supplier_name': 'Miller-Martinez',
#    'current_stock_quantity': 874,
#    'reorder_level': 50},
#   {'product_name': 'Story Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 510,
#    'reorder_level': 116},
#   {'product_name': 'Suddenly Device',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 372,
#    'reorder_level': 183},
#   {'product_name': 'Suddenly Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'current_stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_name': 'Summer Device',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 320,
#    'reorder_level': 96},
#   {'product_name': 'Sure Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 309,
#    'reorder_level': 125},
#   {'product_name': 'Surface Shirt',
#    'supplier_name': 'Vega, Cook and Miller',
#    'current_stock_quantity': 530,
#    'reorder_level': 137},
#   {'product_name': 'System Snack',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 503,
#    'reorder_level': 138},
#   {'product_name': 'Tax Device',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 644,
#    'reorder_level': 84},
#   {'product_name': 'Teacher Toy',
#    'supplier_name': 'Barrett Ltd',
#    'current_stock_quantity': 436,
#    'reorder_level': 189},
#   {'product_name': 'Thank Shirt',
#    'supplier_name': 'Barker, White and Carson',
#    'current_stock_quantity': 902,
#    'reorder_level': 83},
#   {'product_name': 'These Snack',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 998,
#    'reorder_level': 163},
#   {'product_name': 'This Snack',
#    'supplier_name': 'Tran LLC',
#    'current_stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'current_stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 936,
#    'reorder_level': 133},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Williams Ltd',
#    'current_stock_quantity': 451,
#    'reorder_level': 57},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Henderson LLC',
#    'current_stock_quantity': 248,
#    'reorder_level': 118},
#   {'product_name': 'Throughout Toy',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 192,
#    'reorder_level': 118},
#   {'product_name': 'Throw Device',
#    'supplier_name': 'Young, Browning and Ware',
#    'current_stock_quantity': 862,
#    'reorder_level': 191},
#   {'product_name': 'Throw Toy',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_name': 'Tough Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'current_stock_quantity': 660,
#    'reorder_level': 154},
#   {'product_name': 'Town Toy',
#    'supplier_name': 'Morgan Inc',
#    'current_stock_quantity': 376,
#    'reorder_level': 182},
#   {'product_name': 'Treat Device',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'current_stock_quantity': 122,
#    'reorder_level': 89},
#   {'product_name': 'Trouble Table',
#    'supplier_name': 'Moss-Evans',
#    'current_stock_quantity': 826,
#    'reorder_level': 166},
#   {'product_name': 'True Snack',
#    'supplier_name': 'Moody-Vang',
#    'current_stock_quantity': 741,
#    'reorder_level': 200},
#   {'product_name': 'Truth Device',
#    'supplier_name': 'Lloyd and Sons',
#    'current_stock_quantity': 570,
#    'reorder_level': 78},
#   {'product_name': 'Value Table',
#    'supplier_name': 'Douglas Ltd',
#    'current_stock_quantity': 480,
#    'reorder_level': 199},
#   {'product_name': 'Wait Toy',
#    'supplier_name': 'Mann-Marshall',
#    'current_stock_quantity': 164,
#    'reorder_level': 164},
#   {'product_name': 'Way Snack',
#    'supplier_name': 'Hall-Brown',
#    'current_stock_quantity': 725,
#    'reorder_level': 77},
#   {'product_name': 'Where Toy',
#    'supplier_name': 'Taylor-Love',
#    'current_stock_quantity': 848,
#    'reorder_level': 80},
#   {'product_name': 'White Table',
#    'supplier_name': 'Morgan-Andrews',
#    'current_stock_quantity': 702,
#    'reorder_level': 143},
#   {'product_name': 'Whom Table',
#    'supplier_name': 'Hudson Inc',
#    'current_stock_quantity': 727,
#    'reorder_level': 186},
#   {'product_name': 'Whose Snack',
#    'supplier_name': 'Wong Group',
#    'current_stock_quantity': 182,
#    'reorder_level': 177},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Rogers-Greene',
#    'current_stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Harris-Cummings',
#    'current_stock_quantity': 839,
#    'reorder_level': 193},
#   {'product_name': 'Writer Table',
#    'supplier_name': 'Anderson-Thompson',
#    'current_stock_quantity': 700,
#    'reorder_level': 198}],
#  'Product needing Reorder': [{'product_id': 19,
#    'product_name': 'Next Device',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_id': 36,
#    'product_name': 'Race Device',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_id': 46,
#    'product_name': 'Close Toy',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_id': 50,
#    'product_name': 'Hard Snack',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_id': 51,
#    'product_name': 'Staff Shirt',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_id': 58,
#    'product_name': 'Floor Toy',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_id': 62,
#    'product_name': 'Throw Toy',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_id': 100,
#    'product_name': 'Fund Table',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_id': 108,
#    'product_name': 'Executive Table',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_id': 110,
#    'product_name': 'However Table',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_id': 113,
#    'product_name': 'Certain Device',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_id': 132,
#    'product_name': 'This Snack',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_id': 136,
#    'product_name': 'Within Toy',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_id': 137,
#    'product_name': 'Least Table',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_id': 144,
#    'product_name': 'Building Snack',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_id': 150,
#    'product_name': 'Return Table',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_id': 153,
#    'product_name': 'Security Shirt',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_id': 154,
#    'product_name': 'Manage Snack',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_id': 160,
#    'product_name': 'Suddenly Table',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_id': 165,
#    'product_name': 'Nor Snack',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_id': 167,
#    'product_name': 'Discuss Toy',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_id': 169,
#    'product_name': 'Four Shirt',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_id': 173,
#    'product_name': 'Real Snack',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_id': 180,
#    'product_name': 'Door Toy',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_id': 185,
#    'product_name': 'Couple Shirt',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_id': 192,
#    'product_name': 'Thought Toy',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_id': 199,
#    'product_name': 'Book Device',
#    'stock_quantity': 46,
#    'reorder_level': 66}]}

# %%
def  AddNewProductManualID(cursor,db,p_name,p_category,p_price,p_stock,p_reorder,p_supplier):
    proc_call = "call  AddNewProductManualID(%s, %s, %s, %s, %s, %s)"
    params = p_name,P_category,p_price,p_stock,p_reorder,p_supplier
    cursor.execute(proc_call, params)
    db.commit()

# %%
def get_categories(cursor):
    k="SELECT DISTINCT category FROM products ORDER BY category"
    cursor.execute(k)
    rows=cursor.fetchall()
    mylist = []
    for row in rows:
        #print(row['category'])
        mylist.append(row['category'])
    return mylist
get_categories(cursor)
# Out:
# ['Clothing', 'Electronics', 'Furniture', 'Groceries', 'Toys']

# %%
def get_supplier(cursor):
    cursor.execute("SELECT supplier_id,supplier_name from suppliers order by supplier_name")
    return cursor.fetchall()
get_supplier(cursor)
# Out:
# [{'supplier_id': 1, 'supplier_name': 'Anderson-Thompson'},
#  {'supplier_id': 48, 'supplier_name': 'Armstrong-Vance'},
#  {'supplier_id': 24, 'supplier_name': 'Barker, White and Carson'},
#  {'supplier_id': 25, 'supplier_name': 'Barrett Ltd'},
#  {'supplier_id': 3, 'supplier_name': 'Baxter-Meadows'},
#  {'supplier_id': 19, 'supplier_name': 'Charles Inc'},
#  {'supplier_id': 41, 'supplier_name': 'Clark Group'},
#  {'supplier_id': 23, 'supplier_name': 'Douglas Ltd'},
#  {'supplier_id': 32, 'supplier_name': 'Elliott-Ayers'},
#  {'supplier_id': 7, 'supplier_name': 'Evans Inc'},
#  {'supplier_id': 27, 'supplier_name': 'Franklin, Kane and Price'},
#  {'supplier_id': 15, 'supplier_name': 'Freeman-Gordon'},
#  {'supplier_id': 13, 'supplier_name': 'Gallagher-Miller'},
#  {'supplier_id': 17, 'supplier_name': 'Gomez PLC'},
#  {'supplier_id': 40, 'supplier_name': 'Hall-Brown'},
#  {'supplier_id': 38, 'supplier_name': 'Harris-Cummings'},
#  {'supplier_id': 42, 'supplier_name': 'Henderson LLC'},
#  {'supplier_id': 50, 'supplier_name': 'Hensley-Branch'},
#  {'supplier_id': 22, 'supplier_name': 'Hudson Inc'},
#  {'supplier_id': 29, 'supplier_name': 'Johnson-Bass'},
#  {'supplier_id': 37, 'supplier_name': 'Kaufman Ltd'},
#  {'supplier_id': 8, 'supplier_name': 'Lawrence, Garcia and Hernandez'},
#  {'supplier_id': 30, 'supplier_name': 'Lloyd and Sons'},
#  {'supplier_id': 21, 'supplier_name': 'Mann-Marshall'},
#  {'supplier_id': 12, 'supplier_name': 'Mendoza-Jones'},
#  {'supplier_id': 6, 'supplier_name': 'Middleton LLC'},
#  {'supplier_id': 14, 'supplier_name': 'Miller-Martinez'},
#  {'supplier_id': 34, 'supplier_name': 'Moody-Vang'},
#  {'supplier_id': 49, 'supplier_name': 'Morgan Inc'},
#  {'supplier_id': 47, 'supplier_name': 'Morgan-Andrews'},
#  {'supplier_id': 18, 'supplier_name': 'Moss-Evans'},
#  {'supplier_id': 10, 'supplier_name': 'Newton, Valencia and Carr'},
#  {'supplier_id': 20, 'supplier_name': 'Ortega-Mahoney'},
#  {'supplier_id': 45, 'supplier_name': 'Patrick, Walter and Harrison'},
#  {'supplier_id': 35, 'supplier_name': 'Perez, Price and Wallace'},
#  {'supplier_id': 33, 'supplier_name': 'Reynolds-Phillips'},
#  {'supplier_id': 44, 'supplier_name': 'Rogers-Greene'},
#  {'supplier_id': 43, 'supplier_name': 'Rowe PLC'},
#  {'supplier_id': 2, 'supplier_name': 'Rowland Ltd'},
#  {'supplier_id': 5, 'supplier_name': 'Smith, Kennedy and Moreno'},
#  {'supplier_id': 28, 'supplier_name': 'Stewart, Williams and Cox'},
#  {'supplier_id': 31, 'supplier_name': 'Taylor-Love'},
#  {'supplier_id': 26, 'supplier_name': 'Tran LLC'},
#  {'supplier_id': 16, 'supplier_name': 'Tucker-Arnold'},
#  {'supplier_id': 39, 'supplier_name': 'Turner-Davis'},
#  {'supplier_id': 11, 'supplier_name': 'Vega, Cook and Miller'},
#  {'supplier_id': 46, 'supplier_name': 'Williams Ltd'},
#  {'supplier_id': 4, 'supplier_name': 'Wilson, Graham and Williams'},
#  {'supplier_id': 36, 'supplier_name': 'Wong Group'},
#  {'supplier_id': 9, 'supplier_name': 'Young, Browning and Ware'}]

# %%
suppliers = get_supplier(cursor)
[s['supplier_name'] for s in suppliers]
#[s['supplier_id'] for s in suppliers]
# Out:
# ['Anderson-Thompson',
#  'Armstrong-Vance',
#  'Barker, White and Carson',
#  'Barrett Ltd',
#  'Baxter-Meadows',
#  'Charles Inc',
#  'Clark Group',
#  'Douglas Ltd',
#  'Elliott-Ayers',
#  'Evans Inc',
#  'Franklin, Kane and Price',
#  'Freeman-Gordon',
#  'Gallagher-Miller',
#  'Gomez PLC',
#  'Hall-Brown',
#  'Harris-Cummings',
#  'Henderson LLC',
#  'Hensley-Branch',
#  'Hudson Inc',
#  'Johnson-Bass',
#  'Kaufman Ltd',
#  'Lawrence, Garcia and Hernandez',
#  'Lloyd and Sons',
#  'Mann-Marshall',
#  'Mendoza-Jones',
#  'Middleton LLC',
#  'Miller-Martinez',
#  'Moody-Vang',
#  'Morgan Inc',
#  'Morgan-Andrews',
#  'Moss-Evans',
#  'Newton, Valencia and Carr',
#  'Ortega-Mahoney',
#  'Patrick, Walter and Harrison',
#  'Perez, Price and Wallace',
#  'Reynolds-Phillips',
#  'Rogers-Greene',
#  'Rowe PLC',
#  'Rowland Ltd',
#  'Smith, Kennedy and Moreno',
#  'Stewart, Williams and Cox',
#  'Taylor-Love',
#  'Tran LLC',
#  'Tucker-Arnold',
#  'Turner-Davis',
#  'Vega, Cook and Miller',
#  'Williams Ltd',
#  'Wilson, Graham and Williams',
#  'Wong Group',
#  'Young, Browning and Ware']

# %%
mylist = []
for s in suppliers:
    #print(s['supplier_id'])
    mylist.append(s['supplier_id'])
mylist
# Out:
# [1,
#  48,
#  24,
#  25,
#  3,
#  19,
#  41,
#  23,
#  32,
#  7,
#  27,
#  15,
#  13,
#  17,
#  40,
#  38,
#  42,
#  50,
#  22,
#  29,
#  37,
#  8,
#  30,
#  21,
#  12,
#  6,
#  14,
#  34,
#  49,
#  47,
#  18,
#  10,
#  20,
#  45,
#  35,
#  33,
#  44,
#  43,
#  2,
#  5,
#  28,
#  31,
#  26,
#  16,
#  39,
#  11,
#  46,
#  4,
#  36,
#  9]
